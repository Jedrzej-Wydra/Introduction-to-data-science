# %% [markdown]
# # Student 1

# %% [markdown]
# ## Zadanie 1
# Dane:
# nums = [5, 12, -3, 8, 10, 2]
#
# Proszę obliczyć:
# 1. Sumę liczb parzystych.
# 2. Średnią wszystkich dodatnich elementów.

# %% [markdown]
# ## Zadanie 2
# Proszę utworzyć ramkę danych z danymi:
#
# | hero    | strength | agility |
# |---------|----------|---------|
# | Bilbo   | 8        | 6       |
# | Thorin  | 12       | 5       |
# | Kili    | 9        | 7       |
#
# Proszę dodać kolumnę "total = strength + agility" i wypisać postać o najwyższym "total".

# %% [markdown]
# ## Zadanie 3
# Proszę utworzyć macierz NumPy:
#
# [[2, 4, 6],
#  [1, 3, 5]]
#
# Proszę wypisać elementy większe niż 3 oraz policzyć ich liczbę.

# %% [markdown]
# # Student 2

# %% [markdown]
# ## Zadanie 1
# Dane:
# names = ["Leia", "Han", "Luke", "Lando"]
#
# Proszę wypisać listę długości imion oraz wskazać imię najkrótsze.

# %% [markdown]
# ## Zadanie 2
# Proszę utworzyć ramkę danych:
#
# | drink      | caffeine |
# |------------|----------|
# | matcha     | 70       |
# | yerba      | 85       |
# | espresso   | 110      |
# | cola       | 34       |
#
# Proszę obliczyć średnią zawartość kofeiny i wypisać napoje o wartości powyżej średniej.

# %% [markdown]
# ## Zadanie 3
# Dane:
# a = np.array([3, 9, 12, 18])
# b = np.array([1, 3, 4, 6])
#
# Proszę obliczyć element-wise iloraz i sumę wszystkich wyników większych niż 2.

# %% [markdown]
# # Student 3

# %% [markdown]
# ## Zadanie 1
#
# Dane:
# data = [2, 2, 3, 4, 4, 4, 5]
#
# Proszę obliczyć najczęściej występującą wartość.

# %% [markdown]
# ## Zadanie 2
# Proszę utworzyć ramkę danych:
#
# | city    | temp |
# |---------|------|
# | Tokyo   | 22   |
# | Oslo    | 14   |
# | Madrid  | 26   |
#
# Proszę obliczyć medianę temperatur.

# %% [markdown]
# ## Zadanie 3
# Proszę utworzyć macierz NumPy:
#
# [[1, 0, 5],
#  [2, 3, 1],
#  [4, 1, 2]]
#
# Proszę policzyć sumę wartości z przekątnej.

# %% [markdown]
# # Student 4

# %% [markdown]
# ## Zadanie 1
# Dane:
# chars = ["Gandalf", "Frodo", "Samwise"]
#
# Proszę utworzyć słownik {imię: długość imienia}.

# %% [markdown]
# ## Zadanie 2
# Proszę utworzyć ramkę danych:
#
# | food   | calories |
# |--------|----------|
# | ramen  | 450      |
# | udon   | 380      |
# | sushi  | 300      |
#
# Proszę dodać kolumnę "kcal_per_100g = calories / 1.5".

# %% [markdown]
# ## Zadanie 3
# Proszę utworzyć tablicę NumPy:
# arr = np.array([10, 20, 30, 40, 50])
#
# Proszę wypisać różnice między kolejnymi elementami.

# %% [markdown]
# # Student 5

# %% [markdown]
# ## Zadanie 1
# Dane:
# vals = [4, 9, 16, 25]
#
# Proszę obliczyć pierwiastki kwadratowe wszystkich elementów. Proszę korzystać tylko z bazowego Pythona.

# %% [markdown]
# ## Zadanie 2
# Proszę utworzyć ramkę danych:
#
# | robot   | version |
# |---------|---------|
# | R2-D2   | 3.1     |
# | C-3PO   | 2.8     |
# | BB-8    | 4.0     |
#
# Proszę wypisać roboty z wersją ≥ 3.

# %% [markdown]
# ## Zadanie 3
# Proszę utworzyć macierz:
# m = np.array([[2, 7], [1, 5]])
#
# Proszę policzyć wyznacznik macierzy korzystając tylko z bazowego Pythona.

# %% [markdown]
# # Student 6

# %% [markdown]
# ## Zadanie 1
#
# Dane:
# words = ["science", "data", "python", "force"]
#
# Proszę policzyć liczbę liter "o" w całej liście.

# %% [markdown]
# ## Zadanie 2
#
# Proszę utworzyć ramkę danych:
#
# | person  | iq |
# |---------|----|
# | Morty   | 110 |
# | Rick    | 180 |
# | Summer  | 115 |
#
# Proszę wypisać osoby z IQ większym niż średnia.

# %% [markdown]
# ## Zadanie 3
# Proszę utworzyć macierz NumPy:
#
# [[5, 1, 0],
#  [2, 8, 3],
#  [1, 0, 2]]
#
# Proszę policzyć sumę elementów w kolumnie nr 1.

# %% [markdown]
# # Student 7

# %% [markdown]
# ## Zadanie 1
#
# Dane:
# scores = [55, 70, 92, 88, 60]
#
# Proszę znormalizować dane (przeskalować do zakresu 0–1).

# %% [markdown]
# ## Zadanie 2
#
# Proszę utworzyć ramkę danych:
#
# | animal     | weight |
# |------------|--------|
# | hedgehog   | 1.2    |
# | otter      | 11.0   |
# | panda      | 80.0   |
#
# Proszę policzyć średnią masę i wskazać zwierzę o wadze najbliższej średniej.

# %% [markdown]
# ## Zadanie 3
#
# Dane:
# v = np.array([1, 4, 9, 16])
#
# Proszę wypisać elementy, których pierwiastek jest większy niż 3.

# %% [markdown]
# # Student 8

# %% [markdown]
# ## Zadanie 1
#
# Dane:
# nums = [3, 7, 11, 15, 19]
#
# Proszę policzyć sumę liczb pierwszych.

# %% [markdown]
# ## Zadanie 2
#
# Proszę utworzyć ramkę danych:
#
# | book       | pages |
# |------------|-------|
# | Dune       | 540   |
# | Mistborn   | 620   |
# | The Hobbit | 310   |
#
# Proszę wypisać książki o liczbie stron większej niż mediana.

# %% [markdown]
# ## Zadanie 3
#
# Proszę utworzyć macierz:
#
# [[1, 2, 3],
#  [4, 5, 6]]
#
# Proszę zsumować wszystkie elementy większe niż 2.

# %% [markdown]
# # Student 9

# %% [markdown]
# ## Zadanie 1
# Dane:
# chars = ["Neo", "Trinity", "Morpheus"]
#
# Proszę zwrócić listę imion zaczynających się na spółgłoskę.

# %% [markdown]
# ## Zadanie 2
# Proszę utworzyć ramkę danych:
#
# | fruit | sugar |
# |-------|--------|
# | apple | 10     |
# | pear  | 9      |
# | grape | 15     |
#
# Proszę dodać kolumnę "ratio = sugar / max(sugar)".

# %% [markdown]
# ## Zadanie 3
#
# Dane:
# n = np.array([2, 5, 8, 11])
#
# Proszę policzyć liczbę elementów podzielnych przez 2 lub 3.

# %% [markdown]
# # Student 10

# %% [markdown]
# ## Zadanie 1
# Dane:
# data = [0.2, 0.5, 0.8, 1.0]
#
# Proszę przeskalować dane do zakresu 0–10.

# %% [markdown]
# ## Zadanie 2
# Proszę utworzyć DataFrame:
#
# | champion | power |
# |----------|--------|
# | Ahri     | 89     |
# | Garen    | 76     |
# | Lux      | 91     |
#
# Proszę wyświetlić championów o power > 80.

# %% [markdown]
# ## Zadanie 3
# Dane:
# p = np.array([2, 4, 8, 16, 32])
#
# Proszę obliczyć log₂ z elementów (można własną funkcją).

# %% [markdown]
# # Student 11

# %% [markdown]
# ## Zadanie 1
# Dane:
# times = [12.4, 10.1, 11.7, 9.9]
#
# Proszę wypisać czas najszybszego zawodnika oraz różnicę między najgorszym a najlepszym.

# %% [markdown]
# ## Zadanie 2
# Proszę utworzyć rankę danych:
#
# | car      | speed |
# |----------|--------|
# | Tesla    | 210    |
# | Mustang  | 250    |
# | Civic    | 190    |
#
# Proszę wypisać samochód, którego prędkość jest równa medianie prędkości.

# %% [markdown]
# ## Zadanie 3
# Proszę utworzyć macierz:
#
# [[2, 4],
#  [6, 8]]
#
# Proszę wypisać sumę elementów parzystych.

# %% [markdown]
# # Student 12

# %% [markdown]
# ## Zadanie 1
# Dane:
# movies = ["Inception", "Memento", "Tenet"]
#
# Proszę zwrócić listę długości tytułów oraz najdłuższy tytuł.

# %% [markdown]
# ## Zadanie 2
# Proszę utworzyć ramkę danych:
#
# | tea    | temp |
# |--------|-------|
# | green  | 70    |
# | black  | 95    |
# | white  | 80    |
#
# Proszę policzyć średnią temperaturę i wypisać herbaty wymagające temperatury wyższej niż średnia.

# %% [markdown]
# ## Zadanie 3
# Dane:
# v = np.array([3, 6, 12, 24])
#
# Proszę policzyć liczbę elementów będących potęgami liczby 3.

# %% [markdown]
# # Student 13

# %% [markdown]
# ## Zadanie 1
# Dane:
# letters = ["a", "b", "c", "d"]
#
# Proszę wygenerować słownik {litera: kod ASCII}.

# %% [markdown]
# ## Zadanie 2
# Proszę utworzyć ramkę danych:
#
# | pokemon    | hp |
# |------------|-----|
# | Pikachu    | 35  |
# | Bulbasaur  | 45  |
# | Charmander | 39  |
#
# Proszę dodać kolumnę "hp2 = hp**2".

# %% [markdown]
# ## Zadanie 3
# Proszę utworzyć macierz:
#
# [[1, 2],
#  [3, 4],
#  [5, 6]]
#
# Proszę policzyć sumę wartości w każdym wierszu (wynik: wektor długości 3).

# %% [markdown]
# # Student 14

# %% [markdown]
# ## Zadanie 1
# Dane:
# grades = [2, 4, 5, 3, 5]
# wagi = [1, 2, 3, 1, 2]
#
# Proszę obliczyć średnią ważoną.

# %% [markdown]
# ## Zadanie 2
# Proszę utworzyć ramkę danych:
#
# | planet | mass |
# |--------|-------|
# | Mars   | 0.11  |
# | Venus  | 0.82  |
# | Earth  | 1.00  |
#
# Proszę obliczyć udział procentowy masy każdej planety względem sumy.

# %% [markdown]
# ## Zadanie 3
# Proszę utworzyć macierz:
#
# [[1, 4, 9],
#  [2, 5, 10],
#  [3, 6, 11]]
#
# Proszę wypisać średnią w każdej kolumnie.

# %% [markdown]
# # Student 15

# %% [markdown]
# ## Zadanie 1
# Dane:
# temps = [18, 21, 20, 25, 17]
#
# Proszę policzyć odchylenie standardowe korzystając wyłącznie z bazowego Pythona.

# %% [markdown]
# ## Zadanie 2
# Proszę utworzyć ramkę danych:
#
# | wizard   | mana |
# |----------|-------|
# | Merlin   | 150   |
# | Morgana  | 180   |
# | Radagast | 120   |
#
# Proszę wypisać czarodziei z maną powyżej mediany.

# %% [markdown]
# ## Zadanie 3
# Dane:
# a = np.array([1, 2, 3, 4, 5])
#
# Proszę policzyć sumę kwadratów elementów.

# %% [markdown]
# # Lepiej zdawać długie, czy krótkie testy?

# %%
# Pakiety
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
from tqdm.notebook import tqdm

# %% [markdown]
# ## Rozkład jednostajny

# %%
fig, axes = plt.subplots(4, 2, figsize=(12, 10))

n_values = [1, 10, 50, 100]

for i, n in enumerate(n_values):
    obs = np.random.uniform(0, 1, (1000, n))
    means = np.mean(obs, axis=1)

    sns.histplot(obs.ravel(), kde=True, stat="density", color="blue", alpha=0.3, ax=axes[i, 0])
    x = np.linspace(np.min(obs), np.max(obs), 100)
    mu, sigma = np.mean(obs), np.std(obs)
    y = norm.pdf(x, mu, sigma)
    axes[i, 0].plot(x, y, color="black", linestyle="--", linewidth=2, label="Normal PDF")
    axes[i, 0].set_title(f"Histogram i gęstość (obserwacje), n={n}")
    axes[i, 0].set_xlabel("Wartości")
    axes[i, 0].set_ylabel("Gęstość")

    sns.histplot(means, kde=True, stat="density", color="green", alpha=0.3, ax=axes[i, 1])
    x = np.linspace(np.min(means), np.max(means), 100)
    mu, sigma = np.mean(means), np.std(means)
    y = norm.pdf(x, mu, sigma)
    axes[i, 1].plot(x, y, color="black", linestyle="--", linewidth=2, label="Normal PDF")
    axes[i, 1].set_title(f"Histogram i gęstość (średnie), n={n}")
    axes[i, 1].set_xlabel("Wartości")
    axes[i, 1].set_ylabel("Gęstość")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Rozkład t

# %%
fig, axes = plt.subplots(4, 2, figsize=(12, 10))

n_values = [1, 10, 50, 100]

for i, n in enumerate(n_values):
    obs = np.random.standard_t(df=3, size=(1000, n))
    means = np.mean(obs, axis=1)

    sns.histplot(obs.ravel(), kde=True, stat="density", color="blue", alpha=0.3, ax=axes[i, 0])
    x = np.linspace(np.min(obs), np.max(obs), 100)
    mu, sigma = np.mean(obs), np.std(obs)
    y = norm.pdf(x, mu, sigma)
    axes[i, 0].plot(x, y, color="black", linestyle="--", linewidth=2, label="Normal PDF")
    axes[i, 0].set_title(f"Histogram i gęstość (obserwacje), n={n}")
    axes[i, 0].set_xlabel("Wartości")
    axes[i, 0].set_ylabel("Gęstość")

    sns.histplot(means, kde=True, stat="density", color="green", alpha=0.3, ax=axes[i, 1])
    x = np.linspace(np.min(means), np.max(means), 100)
    mu, sigma = np.mean(means), np.std(means)
    y = norm.pdf(x, mu, sigma)
    axes[i, 1].plot(x, y, color="black", linestyle="--", linewidth=2, label="Normal PDF")
    axes[i, 1].set_title(f"Histogram i gęstość (średnie), n={n}")
    axes[i, 1].set_xlabel("Wartości")
    axes[i, 1].set_ylabel("Gęstość")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Rozkład chi-kwadrat

# %%
fig, axes = plt.subplots(4, 2, figsize=(12, 10))

n_values = [1, 10, 50, 100]

for i, n in enumerate(n_values):
    obs = np.random.chisquare(df=2, size=(1000, n))
    means = np.mean(obs, axis=1)

    sns.histplot(obs.ravel(), kde=True, stat="density", color="blue", alpha=0.3, ax=axes[i, 0])
    x = np.linspace(np.min(obs), np.max(obs), 100)
    mu, sigma = np.mean(obs), np.std(obs)
    y = norm.pdf(x, mu, sigma)
    axes[i, 0].plot(x, y, color="black", linestyle="--", linewidth=2, label="Normal PDF")
    axes[i, 0].set_title(f"Histogram i gęstość (obserwacje), n={n}")
    axes[i, 0].set_xlabel("Wartości")
    axes[i, 0].set_ylabel("Gęstość")

    sns.histplot(means, kde=True, stat="density", color="green", alpha=0.3, ax=axes[i, 1])
    x = np.linspace(np.min(means), np.max(means), 100)
    mu, sigma = np.mean(means), np.std(means)
    y = norm.pdf(x, mu, sigma)
    axes[i, 1].plot(x, y, color="black", linestyle="--", linewidth=2, label="Normal PDF")
    axes[i, 1].set_title(f"Histogram i gęstość (średnie), n={n}")
    axes[i, 1].set_xlabel("Wartości")
    axes[i, 1].set_ylabel("Gęstość")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Rozkład Weibulla

# %%
fig, axes = plt.subplots(4, 2, figsize=(12, 10))

n_values = [1, 10, 50, 100]

for i, n in enumerate(n_values):
    obs = np.random.weibull(a=200, size=(1000, n))
    means = np.mean(obs, axis=1)

    sns.histplot(obs.ravel(), kde=True, stat="density", color="blue", alpha=0.3, ax=axes[i, 0])
    x = np.linspace(np.min(obs), np.max(obs), 100)
    mu, sigma = np.mean(obs), np.std(obs)
    y = norm.pdf(x, mu, sigma)
    axes[i, 0].plot(x, y, color="black", linestyle="--", linewidth=2, label="Normal PDF")
    axes[i, 0].set_title(f"Histogram i gęstość (obserwacje), n={n}")
    axes[i, 0].set_xlabel("Wartości")
    axes[i, 0].set_ylabel("Gęstość")

    sns.histplot(means, kde=True, stat="density", color="green", alpha=0.3, ax=axes[i, 1])
    x = np.linspace(np.min(means), np.max(means), 100)
    mu, sigma = np.mean(means), np.std(means)
    y = norm.pdf(x, mu, sigma)
    axes[i, 1].plot(x, y, color="black", linestyle="--", linewidth=2, label="Normal PDF")
    axes[i, 1].set_title(f"Histogram i gęstość (średnie), n={n}")
    axes[i, 1].set_xlabel("Wartości")
    axes[i, 1].set_ylabel("Gęstość")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Rozkład dwumianowy

# %%
fig, axes = plt.subplots(4, 2, figsize=(12, 10))

n_values = [1, 10, 50, 100]

for i, n in enumerate(n_values):
    obs = np.random.binomial(n=10, p=0.3, size=(1000, n))
    means = np.mean(obs, axis=1)

    sns.histplot(obs.ravel(), bins = 50, kde=True, stat="density", color="blue", alpha=0.3, ax=axes[i, 0])
    x = np.linspace(np.min(obs), np.max(obs), 100)
    mu, sigma = np.mean(obs), np.std(obs)
    y = norm.pdf(x, mu, sigma)
    axes[i, 0].plot(x, y, color="black", linestyle="--", linewidth=2, label="Normal PDF")
    axes[i, 0].set_title(f"Histogram i gęstość (obserwacje), n={n}")
    axes[i, 0].set_xlabel("Wartości")
    axes[i, 0].set_ylabel("Gęstość")

    sns.histplot(means, kde=True, stat="density", color="green", alpha=0.3, ax=axes[i, 1])
    x = np.linspace(np.min(means), np.max(means), 100)
    mu, sigma = np.mean(means), np.std(means)
    y = norm.pdf(x, mu, sigma)
    axes[i, 1].plot(x, y, color="black", linestyle="--", linewidth=2, label="Normal PDF")
    axes[i, 1].set_title(f"Histogram i gęstość (średnie), n={n}")
    axes[i, 1].set_xlabel("Wartości")
    axes[i, 1].set_ylabel("Gęstość")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Rozkład Poissona

# %%
fig, axes = plt.subplots(4, 2, figsize=(12, 10))

n_values = [1, 10, 50, 100]

for i, n in enumerate(n_values):
    obs = np.random.poisson(lam=3, size=(1000, n))
    means = np.mean(obs, axis=1)

    sns.histplot(obs.ravel(), bins = 50, kde=True, stat="density", color="blue", alpha=0.3, ax=axes[i, 0])
    x = np.linspace(np.min(obs), np.max(obs), 100)
    mu, sigma = np.mean(obs), np.std(obs)
    y = norm.pdf(x, mu, sigma)
    axes[i, 0].plot(x, y, color="black", linestyle="--", linewidth=2, label="Normal PDF")
    axes[i, 0].set_title(f"Histogram i gęstość (obserwacje), n={n}")
    axes[i, 0].set_xlabel("Wartości")
    axes[i, 0].set_ylabel("Gęstość")

    sns.histplot(means, kde=True, stat="density", color="green", alpha=0.3, ax=axes[i, 1])
    x = np.linspace(np.min(means), np.max(means), 100)
    mu, sigma = np.mean(means), np.std(means)
    y = norm.pdf(x, mu, sigma)
    axes[i, 1].plot(x, y, color="black", linestyle="--", linewidth=2, label="Normal PDF")
    axes[i, 1].set_title(f"Histogram i gęstość (średnie), n={n}")
    axes[i, 1].set_xlabel("Wartości")
    axes[i, 1].set_ylabel("Gęstość")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Jak to jest z testami?

# %% [markdown]
# ### Funkcja tworząca test

# %%
def test_initiator(n = 10):
    test = np.zeros((n, 3))
    correct_answer_position = []
    for i in range(n):
        random_number =  np.random.choice(range(3))
        test[i, random_number] = 1
        correct_answer_position.append(random_number)
    correct_answer_position = np.array(correct_answer_position)
    return test, correct_answer_position

# %% [markdown]
# ### Funkcja wybierająca odpowiedź z prawdopodobieństwem p

# %%
def random_answers(test, p):
    questions = test[0]
    positions = test[1]
    answers = []
    for i in range(questions.shape[0]):
        question = questions[i,:]
        position = positions[i]
        probs = np.full(3, (1 - p)/2)
        probs[position] = p
        ans = np.random.choice(question, p = list(probs))
        answers.append(ans)
    return np.array(answers)

# %% [markdown]
# ### Eksperyment

# %%
expected_results = np.zeros((100, 100))
stand_err = np.zeros((100, 100))
for i in tqdm(range(1, 101)):
    for j in range(1, 101):
        answers = random_answers(test_initiator(n = i),j/100)
        expected_results[i - 1, j - 1] = np.mean(answers)
        stand_err[i - 1, j - 1] = np.std(answers)/np.sqrt(i)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Wyniki

sns.heatmap(expected_results,
            cmap="coolwarm",
            annot=False, ax=axes[0])
axes[0].set_xticks(np.arange(5, 100, 5))
axes[0].set_xticklabels(np.arange(5, 100, 5)/100)
axes[0].set_yticks(np.arange(5, 100, 5))
axes[0].set_yticklabels(np.arange(5, 100, 5))
axes[0].set_title("Wyniki")

# Zmienność

sns.heatmap(stand_err,
            cmap="coolwarm",
            annot=False,
            ax=axes[1])
axes[1].set_xticks(np.arange(5, 100, 5))
axes[1].set_xticklabels(np.arange(5, 100, 5)/100)
axes[1].set_yticks(np.arange(5, 100, 5))
axes[1].set_yticklabels(np.arange(5, 100, 5))
axes[1].set_title("Zmienność")

plt.show()

# %%
fig, axes = plt.subplots(3, 2, figsize=(12, 10))
x = np.arange(1, 101) / 100


rows = [15, 30, 45, 60, 75, 90]
colors = ['b', 'c', 'g', 'm', 'r', 'y']

for i, row in enumerate(rows):
    ax = axes[i // 2, i % 2]

    # Pobranie danych
    y = expected_results[row, :]
    y_min = y - 1.96 * stand_err[row, :]
    y_max = y + 1.96 * stand_err[row, :]

    # Wykres
    ax.plot(x, y, label=f"Test z {row} pytaniami", color=colors[i])
    ax.fill_between(x, y_min, y_max, color=colors[i], alpha=0.2)
    ax.set_title(f"Test z {row} pytaniami")
    ax.set_xlabel("Prawdopodobieństwo poprawnej odpowiedzi")
    ax.set_ylabel("Wynik z testu")
    ax.set_ylim(0, 1)
    ax.axhline(y=0.6, color='black', linestyle='--')
    ax.legend()

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(3, 2, figsize=(12, 10))
x = np.arange(1, 101)


columns = [15, 30, 45, 60, 75, 90]
colors = ['b', 'c', 'g', 'm', 'r', 'y']

for i, column in enumerate(columns):
    ax = axes[i // 2, i % 2]

    y = expected_results[:, column]
    y_min = y - 1.96 * stand_err[:, column]
    y_max = y + 1.96 * stand_err[:, column]

    ax.plot(x, y, label=f"Prawdopodobieństwo równe {column/100}", color=colors[i])
    ax.fill_between(x, y_min, y_max, color=colors[i], alpha=0.2)
    ax.set_title(f"Poprawna odpowiedź wybiera a prawdopodobieństwem {column/100}")
    ax.set_xlabel("Liczba pytań")
    ax.set_ylabel("Wynik z testu")
    ax.set_ylim(0, 1)
    ax.axhline(y=column/100, color='black', linestyle='--')
    ax.legend()

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(3, 2, figsize=(12, 10))
x = np.arange(1, 101)


columns = [40, 45, 50, 55, 60, 65]
colors = ['b', 'c', 'g', 'm', 'r', 'y']

for i, column in enumerate(columns):
    ax = axes[i // 2, i % 2]
    p = column/100
    y = norm.cdf(0.5, loc=column/100, scale=np.sqrt(p * (1 - p))/np.sqrt(np.arange(1,101)))

    ax.plot(x, y, label=f"Prawdopodobieństwo równe {column/100}", color=colors[i])
    ax.set_title(f"Poprawna odpowiedź wybierana z prawdopodobieństwem {column/100}")
    ax.set_xlabel("Liczba pytań")
    ax.set_ylabel("Prawdopodobieństwo oblania testu")
    ax.set_ylim(0, 1)
    ax.axhline(y=0.5, color='black', linestyle='--')
    ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Spojrzenie dwuwymiarowe

# %%
p_stwo = np.zeros((100, 100))
for i in range(1, 100):
    for j in range(1, 101):
        p = i / 100
        p_stwo[i - 1, j - 1] = norm.cdf(0.5, loc=p, scale=np.sqrt(p * (1 - p)) / np.sqrt(j))


plt.figure(figsize=(8, 6))
sns.heatmap(p_stwo, cmap="coolwarm", annot=False)


plt.xlabel("Liczba pytań")
plt.ylabel("Prawdopodobieństwo * 100")
plt.title("Prawdopodobieństwo oblania testu")


plt.show()

# %% [markdown]
# # Zadania

# %% [markdown]
# **Zadanie 1.**
#
# Proszę narysować histogramy i esytmatory gęstości jądrowej dla:
# 1. próby wylosowanej z rozkładu P;
# 2. próby powstałej z wyliczenia średnich z prób z rozkładu P.
#
# Jako rozkład P proszę zastosować:
# 1. Rozkład jednostajny;
# 2. Rozkład chi-kwadrat;
# 3. Rozkłąd Weibulla.
#
# Próba średnich powinna mieć sto elementów. Próby z których liczona jest średnia powinny mieć 1, 10, 50 i 100 obserwacji.
#
# Zatem należy otrzymać 24 wykresy.

# %% [markdown]
# **Zadanie 2.**
#
# Proszę napisać funkcję tworzącą test.

# %% [markdown]
# **Zadanie 4.**
#
# Dla liczb pytań: 15, 30, 45, 60, 75, 90, proszę narysować wykresy wynik test vs. prawdopodobieństwo poprawnej odpowiedzi wraz z przedziałami ufności wyliczonymi zgodnie z centralnym twierdzeniem granicznym.

# %% [markdown]
# **Zadanie 5.**
#
# Dla prawdopodobieństw: 0.15, 0.3, 0.45, 0.6, 0.75, 0.9, proszę narysować wykresy wynik test vs. liczba pytań wraz z przedziałami ufności wyliczonymi zgodnie z centralnym twierdzeniem granicznym.
